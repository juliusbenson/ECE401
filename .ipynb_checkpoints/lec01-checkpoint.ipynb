# %% [markdown]
# # ECE 401, Signal Processing
#
# # Lecture 1: Introduction to Signal Processing using Python
#
# This Jupyter notebook was released into the public domain by its author, Mark Hasegawa-Johnson.  Please feel free to re-use or recycle any part of it at will.

# %% [markdown]
# ## 0. Outline of the Course

# %% [markdown]
# Here's the official course description:
#
#     Introduction to signal processing for advanced undergraduates or graduate students in the biological, physical, social, engineering and computer sciences. Representation and processing of continuous-time and discrete-time signals and images using phasors, Fourier series, sampling, FIR filters, discrete-time Fourier transform, Z transform, and IIR filters. Machine problems include processing of music, speech, photographic image, bioelectric, and biomedical image data. Course Information: 4 undergraduate hours. 4 graduate hours. Credit is not given towards graduation for both ECE 310 and ECE 401. Prerequisite: MATH 220.
#
# If you're an ECE student, please note the second-to-last sentence.

# %% [markdown]
# Here are some other links to help you get started:
#
# * The web page for this course is https://courses.engr.illinois.edu/ece401.  There, you can find a list of lectures, and information about grading, assignments, and exams.
# * The textbook is [Signal Processing First](https://www.mathworks.com/academia/books/signal-processing-first-mccellan.html>) by McClellan, Schafer and Yoder.
# * All machine problems in this course will use [python](https://docs.python.org/3/tutorial/appetite.html). Instructions for each machine problem, and some lectures (like this one), will use [Jupyter notebooks](https://jupyter.org/).  If you don't have a lot of previous python experience, I strongly recommend that you install [Anaconda](https://www.anaconda.com/), because it includes pre-installed versions of many of the packages we will use in this course, including Jupyter, [numpy](https://numpy.org), [pyplot](https://matplotlib.org/stable/tutorials/pyplot.html) and [IPython](https://ipython.org/ipython-doc/dev/api/generated/IPython.display.html).
# * If you want to run all of the code in this lecture, you'll also need to install [librosa](https://librosa.org/doc/latest/index.html).  You can do that by running the following code block, which uses the exclamation point (!) to run a system command that installs librosa:

# %%
# !pip install librosa
# Out:
# Collecting librosa
#   Downloading librosa-0.10.2.post1-py3-none-any.whl.metadata (8.6 kB)
# Collecting audioread>=2.1.9 (from librosa)
#   Downloading audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\juliusbenson\anaconda3\lib\site-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\juliusbenson\anaconda3\lib\site-packages (from librosa) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\juliusbenson\anaconda3\lib\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\juliusbenson\anaconda3\lib\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\juliusbenson\anaconda3\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\juliusbenson\anaconda3\lib\site-packages (from librosa) (0.59.1)
# Collecting soundfile>=0.12.1 (from librosa)
#   Downloading soundfile-0.12.1-py2.py3-none-win_amd64.whl.metadata (14 kB)
# Collecting pooch>=1.1 (from librosa)
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa)
#   Downloading soxr-0.4.0-cp312-cp312-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\juliusbenson\anaconda3\lib\site-packages (from librosa) (4.11.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\juliusbenson\anaconda3\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\juliusbenson\anaconda3\lib\site-packages (from librosa) (1.0.3)
# Requirement already satisfied: packaging in c:\users\juliusbenson\anaconda3\lib\site-packages (from lazy-loader>=0.1->librosa) (23.2)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\juliusbenson\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\juliusbenson\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\juliusbenson\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (2.32.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\juliusbenson\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\juliusbenson\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\juliusbenson\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\juliusbenson\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\juliusbenson\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\juliusbenson\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\juliusbenson\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.6.2)
# Downloading librosa-0.10.2.post1-py3-none-any.whl (260 kB)
#    ---------------------------------------- 0.0/260.1 kB ? eta -:--:--
#    ---------------------------------------  256.0/260.1 kB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 260.1/260.1 kB 4.0 MB/s eta 0:00:00
# Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.6 kB ? eta -:--:--
#    ---------------------------------------- 64.6/64.6 kB 3.6 MB/s eta 0:00:00
# Downloading soundfile-0.12.1-py2.py3-none-win_amd64.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ----------------------------------- ---- 0.9/1.0 MB 28.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 15.9 MB/s eta 0:00:00
# Downloading soxr-0.4.0-cp312-cp312-win_amd64.whl (183 kB)
#    ---------------------------------------- 0.0/183.4 kB ? eta -:--:--
#    --------------------------------------- 183.4/183.4 kB 11.5 MB/s eta 0:00:00
# Installing collected packages: soxr, audioread, soundfile, pooch, librosa
# Successfully installed audioread-3.0.1 librosa-0.10.2.post1 pooch-1.8.2 soundfile-0.12.1 soxr-0.4.0

# %% [markdown]
# Great!  Now let's try creating some signals.  Roughly speaking, there are three fundamental types of signals, from which all other signals are constructed: buzz, click, and hiss.
#
# 1. A [periodic](https://en.wikipedia.org/wiki/Periodic_function) audio signal might sound like a *buzz*, or if it's more pleasant, a [tone](https://en.wikipedia.org/wiki/Tone).  A periodic image signal is called [stripes](https://en.wikipedia.org/wiki/Stripe_(pattern)).  [Electrocardiogram](https://en.wikipedia.org/wiki/Electrocardiography) signals and weather patterns are approximately periodic.
# 1. A short-duration audio signal is called an [impulse](https://en.wikipedia.org/wiki/Dirac_delta_function), and sounds like a *click*.  A short-duration image signal is called a *dot* or [point](https://en.wikipedia.org/wiki/Point_(geometry)).
# 1. An unpredictably random audio, electric, or image signal is called a [stochastic process](https://en.wikipedia.org/wiki/Stochastic_process) and sounds like [noise](https://en.wikipedia.org/wiki/Noise).

# %% [markdown]
# ## 1. Periodic Signals (Tones)
#
# First, let's create a pure tone, at the frequency of middle C on the piano.

# %%
import numpy as np
sr = 8000 # sampling rate, [samples/second]
t = np.arange(sr)/sr # labels for the time axis, in units of seconds
middle_C = 255 # middle C on the piano is about 255 Hz
tone = np.sin(2*np.pi*middle_C*t)  # a tone at middle C

# %% [markdown]
# Let's view the waveform.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(14, 5))
plt.plot(t[:500],tone[:500])
plt.xlabel('Time (seconds)')
plt.title('255Hz Pure Tone')
# Out:
# Text(0.5, 1.0, '255Hz Pure Tone')

# %% [markdown]
# Let's view the spectrogram, using librosa.

# %%
import librosa, librosa.display
TONE = librosa.stft(tone)
TONEdb = librosa.amplitude_to_db(abs(TONE))
plt.figure(figsize=(14, 5))
librosa.display.specshow(TONEdb, sr=sr, x_axis='time', y_axis='hz')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# C:\Users\JULIUS~1\AppData\Local\Temp/ipykernel_4800/2302530664.py in <module>
# ----> 1 import librosa, librosa.display
#       2 TONE = librosa.stft(tone)
#       3 TONEdb = librosa.amplitude_to_db(abs(TONE))
#       4 plt.figure(figsize=(14, 5))
#       5 librosa.display.specshow(TONEdb, sr=sr, x_axis='time', y_axis='hz')
#
# ~\anaconda3\lib\site-packages\librosa\display.py in <module>
#      42
#      43 import numpy as np
# ---> 44 from matplotlib import colormaps as mcm
#      45 import matplotlib.axes as mplaxes
#      46 import matplotlib.ticker as mplticker
#
# ImportError: cannot import name 'colormaps' from 'matplotlib' (C:\Users\juliusbenson\anaconda3\lib\site-packages\matplotlib\__init__.py)

# %% [markdown]
# Now let's play the tone, using Ipython.display.audio.

# %%
import IPython.display as ipd
ipd.Audio(tone, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Now I want to write the waveform to a file, so I can open it using Praat or any other interface.  For this I use soundfile: https://pysoundfile.readthedocs.io/en/latest/.  First, we install soundfile in case you don't already have it:

# %%
# !pip install soundfile
# Out:
# Requirement already satisfied: soundfile in c:\users\juliusbenson\anaconda3\lib\site-packages (0.12.1)
# Requirement already satisfied: cffi>=1.0 in c:\users\juliusbenson\anaconda3\lib\site-packages (from soundfile) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\juliusbenson\anaconda3\lib\site-packages (from cffi>=1.0->soundfile) (2.20)

# %% [markdown]
# ... then, use soundfile to save the waveform as an wav file.

# %%
import soundfile as sf
sf.write('tone_255.wav', tone, sr)

# %% [markdown]
# -------------------------------
# ## 2. Impulses (Clicks)
# -------------------------------
# Next, let me create a click.   A click is mostly zeros, with just one high-amplitude sample in the middle.

# %%
click = np.zeros(8000)
click[4000] = 1000 # arbitrary high-amplitude sample
plt.figure(figsize=(14, 5))
plt.plot(t,click)
plt.xlabel('Time (seconds)')
plt.title('Click at 0.5 seconds, with amplitude of 1000')
# Out:
# Text(0.5, 1.0, 'Click at 0.5 seconds, with amplitude of 1000')

# %%
CLICK = librosa.stft(click, hop_length=80, win_length=240)  # 30ms window length, with a 10ms hop between windows
CLICKdb = librosa.amplitude_to_db(abs(CLICK))
plt.figure(figsize=(14, 5))
librosa.display.specshow(CLICKdb, sr=sr, x_axis='time', y_axis='hz')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# C:\Users\JULIUS~1\AppData\Local\Temp/ipykernel_4800/2001016715.py in <module>
#       2 CLICKdb = librosa.amplitude_to_db(abs(CLICK))
#       3 plt.figure(figsize=(14, 5))
# ----> 4 librosa.display.specshow(CLICKdb, sr=sr, x_axis='time', y_axis='hz')
#
# ~\anaconda3\lib\site-packages\lazy_loader\__init__.py in __getattr__(name)
#      77     def __getattr__(name):
#      78         if name in submodules:
# ---> 79             return importlib.import_module(f"{package_name}.{name}")
#      80         elif name in attr_to_modules:
#      81             submod_path = f"{package_name}.{attr_to_modules[name]}"
#
# ~\anaconda3\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# ~\anaconda3\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# ~\anaconda3\lib\importlib\_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~\anaconda3\lib\site-packages\librosa\display.py in <module>
#      42
#      43 import numpy as np
# ---> 44 from matplotlib import colormaps as mcm
#      45 import matplotlib.axes as mplaxes
#      46 import matplotlib.ticker as mplticker
#
# ImportError: cannot import name 'colormaps' from 'matplotlib' (C:\Users\juliusbenson\anaconda3\lib\site-packages\matplotlib\__init__.py)

# %%
ipd.Audio(click, rate=sr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ipd.Audio(click, rate=sr)
#
# NameError: name 'ipd' is not defined

# %%
sf.write('click.wav', click, sr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sf.write('click.wav', click, sr)
#
# NameError: name 'sf' is not defined

# %% [markdown]
# -------------------------------
# ## 3. Stochastic Processes (Noise)
# -------------------------------
# Finally, the third main type of signal: noise.  We'll use the function np.random.randn, which generates 8000 independent samples of a zero-mean, unit-variance [Gaussian random variable](https://en.wikipedia.org/wiki/Normal_distribution).

# %%
import numpy as np
import matplotlib.pyplot as plt
noise = np.random.randn(8000)
plt.figure(figsize=(14, 5))
plt.plot(t[:500],noise[:500])
plt.xlabel('Time (seconds)')
plt.title('Gaussian Noise, Mean=0.0, Variance=1.0')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       2 import matplotlib as plt
#       3 noise = np.random.randn(8000)
# ----> 4 plt.figure(figsize=(14, 5))
#       5 plt.plot(t[:500],noise[:500])
#       6 plt.xlabel('Time (seconds)')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_api\__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'figure'

# %%
plt.figure(figsize=(14, 5))
NOISE = librosa.stft(noise, hop_length=80, win_length=240)
librosa.display.specshow(librosa.amplitude_to_db(abs(NOISE)), sr=sr, x_axis='time', y_axis='hz')

# %%
ipd.Audio(noise, rate=sr)

# %%
sf.write('noise.wav', noise, sr)

# %% [markdown]
# ## 4. Quiz
#
# Go to [the course webpage](https://courses.engr.illinois.edu/ece401), click on "Lectures", then click on today's date.  That link will take you to the [Prairielearn](https://us.prairielearn.com/) page for this course, to today's quiz.
#
# In every lecture this semester, there will be a short quiz for you to try.  Each quiz can be taken as many times as you like; only your highest score will count.  You will be permitted to try the quiz any time during the lecture, or any time during the 23 hours following the end of lecture, without penalty; if you submit the quiz more than 23 hours after the end of lecture, you will suffer a small penalty of 5 percent.

# %% [markdown]
# ## 5. Next Steps
#
# That's all for today!
#
# If you want to learn more about signal processing, you might find it useful to try some of the available audio and video editing tools, for example:
#
# * Interactive tools that combine audio clips into a larger artistic work include IMovie and Garage Band
# * Open-source command-line tools for converting between different audio file formats or sampling rates include sox and ffmpeg
# * Open-source audio editing tools include Audacity
# * Open-source audio annotation tools include ELAN and Praat.
#
# See you next time!
